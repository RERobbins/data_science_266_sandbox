# %% [markdown]
# <a href="https://colab.research.google.com/github/RERobbins/data_science_266_sandbox/blob/main/sbert.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install --quiet sentence-transformers
# !pip install --quiet langchain
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 1.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 15.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 32.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 24.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 45.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 48.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 8.5 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 8.1 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 18.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 49.4/49.4 kB 4.5 MB/s eta 0:00:00

# %%
from langchain.embeddings import HuggingFaceEmbeddings
from sentence_transformers import SentenceTokenizer

# Load a SentenceTokenizer for the paraphrase-multilingual-mpnet-base-v2 model
#tokenizer = SentenceTokenizer(model_name_or_path='paraphrase-multilingual-mpnet-base-v2')

# Input sentence
#input_sentence = "This is an example sentence."

# Tokenize the input sentence
#tokenized_sentence = tokenizer.tokenize(input_sentence)

#print(tokenized_sentence)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-14e9df781ba5> in <cell line: 2>()
#       1 from langchain.embeddings import HuggingFaceEmbeddings
# ----> 2 from sentence_transformers import SentenceTokenizer
#       3
#       4 # Load a SentenceTokenizer for the paraphrase-multilingual-mpnet-base-v2 model
#       5 #tokenizer = SentenceTokenizer(model_name_or_path='paraphrase-multilingual-mpnet-base-v2')
#
# ImportError: cannot import name 'SentenceTokenizer' from 'sentence_transformers' (/usr/local/lib/python3.10/dist-packages/sentence_transformers/__init__.py)
#
# ---------------------------------------------------------------------------
# NOTE: If your import is failing due to a missing package, you can
# manually install dependencies using either !pip or !apt.
#
# To view examples of installing some common dependencies, click the
# ...

# %%
sbert_model_name = 'paraphrase-multilingual-mpnet-base-v2'
sbert_embeddings_model = HuggingFaceEmbeddings(model_name=sbert_model_name)

# %%
passage = "This is a sentence.  This is another sentence.  It is a short paragraph. But it is getting longer now.  Really.  I mean it."

# %%
embedding = sbert_embeddings_model.embed_query(passage)
# Out:
# [0.2545693516731262,
#  -0.055266812443733215,
#  -0.011733077466487885,
#  -0.06972835212945938,
#  -0.0005987426266074181,
#  -0.05709251016378403,
#  0.004418546333909035,
#  -0.05439944565296173,
#  -0.20520058274269104,
#  0.18488606810569763,
#  0.19946043193340302,
#  -0.05819982290267944,
#  -0.01553152222186327,
#  -0.40527668595314026,
#  0.09811349213123322,
#  -0.24582749605178833,
#  -0.023689525201916695,
#  -0.06220589578151703,
#  0.11662569642066956,
#  0.10264260321855545,
#  0.047092802822589874,
#  -0.03203849866986275,
#  -0.010178793221712112,
#  0.02503085322678089,
#  -0.0072503602132201195,
#  0.011918524280190468,
#  0.013731103390455246,
#  -0.030883532017469406,
#  0.06477578729391098,
#  0.0556926354765892,
#  0.048403654247522354,
#  -0.032559528946876526,
#  -0.13231855630874634,
#  -0.042758844792842865,
#  0.04453294351696968,
#  -0.01126636378467083,
#  0.07106378674507141,
#  0.026916224509477615,
#  -0.23366236686706543,
#  0.15605473518371582,
# ...
